# %%
malist = "[1, 2, 3, 4]"
print(malist)
print(type(malist))

#eval : prend un string et change son type en fonction de son contenue
malist = eval(malist)
print(malist)
print(type(malist))
# Out:
# [1, 2, 3, 4]
# <class 'str'>
# [1, 2, 3, 4]
# <class 'list'>

# %%
i = '5'
j = '3.14'

print(type(eval(i)))
print(type(eval(j)))
# Out:
# <class 'int'>
# <class 'float'>

# %%
#calculer nbre de mots par citations
#transformer url dictionnaire
#changer les dates

# %%
import pandas as pd

# %%
# Out:
#                                                 text             author  \
# 0  “The person, be it gentleman or lady, who has ...        Jane Austen
# 1  “A day without sunshine is like, you know, nig...       Steve Martin
# 2  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 3  “Life is what happens to us while we are makin...     Allen Saunders
# 4  “I may not have gone where I intended to go, b...      Douglas Adams
#
#                                                 tags          born_date  \
# 0                      aliteracy,books,classic,humor  December 16, 1775
# 1                               humor,obvious,simile    August 14, 1945
# 2                    misattributed-eleanor-roosevelt   October 11, 1884
# 3  fate,life,misattributed-john-lennon,planning,p...     April 24, 1899
# 4                                    life,navigation     March 11, 1952
#
#                                        born_location  \
# 0  in Steventon Rectory, Hampshire, The United Ki...
# 1                  in Waco, Texas, The United States
# 2                               in The United States
# 3                               in The United States
# 4          in Cambridge, England, The United Kingdom
#
#                                           image_urls  \
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4  https://upload.wikimedia.org/wikipedia/commons...
#
#                                               images
# 0  [{'url': 'https://upload.wikimedia.org/wikiped...
# 1  [{'url': 'https://upload.wikimedia.org/wikiped...
# 2  [{'url': 'https://upload.wikimedia.org/wikiped...
# 3  [{'url': 'https://upload.wikimedia.org/wikiped...
# 4  [{'url': 'https://upload.wikimedia.org/wikiped...

# %% [markdown]
# ## 1. Calcule du nombre de mots par citation

# %%
df['nb_words'] = df['text'].map(lambda x : len(x.replace(r'[^A-Za-z0-9 ]+', '').lower().strip().split()))

# %%
df.head()
# Out:
#                                                 text             author  \
# 0  “The person, be it gentleman or lady, who has ...        Jane Austen
# 1  “A day without sunshine is like, you know, nig...       Steve Martin
# 2  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 3  “Life is what happens to us while we are makin...     Allen Saunders
# 4  “I may not have gone where I intended to go, b...      Douglas Adams
#
#                                                 tags          born_date  \
# 0                      aliteracy,books,classic,humor  December 16, 1775
# 1                               humor,obvious,simile    August 14, 1945
# 2                    misattributed-eleanor-roosevelt   October 11, 1884
# 3  fate,life,misattributed-john-lennon,planning,p...     April 24, 1899
# 4                                    life,navigation     March 11, 1952
#
#                                        born_location  \
# 0  in Steventon Rectory, Hampshire, The United Ki...
# 1                  in Waco, Texas, The United States
# 2                               in The United States
# 3                               in The United States
# 4          in Cambridge, England, The United Kingdom
#
#                                           image_urls  \
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4  https://upload.wikimedia.org/wikipedia/commons...
#
#                                               images  nb_words
# 0  [{'url': 'https://upload.wikimedia.org/wikiped...        19
# 1  [{'url': 'https://upload.wikimedia.org/wikiped...         9
# 2  [{'url': 'https://upload.wikimedia.org/wikiped...        19
# 3  [{'url': 'https://upload.wikimedia.org/wikiped...        12
# 4  [{'url': 'https://upload.wikimedia.org/wikiped...        22

# %% [markdown]
# ## 2. Transormer en dictionnaire le string url "images"

# %%
image = "[{'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Mark_Twain_by_AF_Bradley.jpg/1280px-Mark_Twain_by_AF_Bradley.jpg', 'path': 'full/5aa96ae7741a7f449062a8fa21d9ba04be349c10.jpg', 'checksum': '2c8792bf9e2702de215ea8a5099d31fb', 'status': 'downloaded'}]"

# %%
image
# Out:
# "[{'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Mark_Twain_by_AF_Bradley.jpg/1280px-Mark_Twain_by_AF_Bradley.jpg', 'path': 'full/5aa96ae7741a7f449062a8fa21d9ba04be349c10.jpg', 'checksum': '2c8792bf9e2702de215ea8a5099d31fb', 'status': 'downloaded'}]"

# %%
d_image = eval(image)[0]

# %%
type(d_image)
# Out:
# dict

# %%
d_image
# Out:
# {'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Mark_Twain_by_AF_Bradley.jpg/1280px-Mark_Twain_by_AF_Bradley.jpg',
#  'path': 'full/5aa96ae7741a7f449062a8fa21d9ba04be349c10.jpg',
#  'checksum': '2c8792bf9e2702de215ea8a5099d31fb',
#  'status': 'downloaded'}

# %%
#Transormer de string --> dict
#Parcourir les clés
    #Créer une nouvelle colonnes avec cette clé
    #Parcour cette colonne
    #ajouter la valeurs correspondant

# %%
#Transormer de string --> dictb

# %%
df['images'] = df['images'].map(lambda x: eval(x)[0])

# %%
keys_images = df['images'].at[0].keys()
keys_images
# Out:
# dict_keys(['url', 'path', 'checksum', 'status'])

# %%
for key in keys_images:
    df[key] = ''
    #df['image'].map(lambda x: x[key])
    for index, row in df.iterrows():
        df.at[index, key] = row['images'][key]

# %%
df.head()
# Out:
#                                                 text             author  \
# 0  “The person, be it gentleman or lady, who has ...        Jane Austen
# 1  “A day without sunshine is like, you know, nig...       Steve Martin
# 2  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 3  “Life is what happens to us while we are makin...     Allen Saunders
# 4  “I may not have gone where I intended to go, b...      Douglas Adams
#
#                                                 tags          born_date  \
# 0                      aliteracy,books,classic,humor  December 16, 1775
# 1                               humor,obvious,simile    August 14, 1945
# 2                    misattributed-eleanor-roosevelt   October 11, 1884
# 3  fate,life,misattributed-john-lennon,planning,p...     April 24, 1899
# 4                                    life,navigation     March 11, 1952
#
#                                        born_location  \
# 0  in Steventon Rectory, Hampshire, The United Ki...
# 1                  in Waco, Texas, The United States
# 2                               in The United States
# 3                               in The United States
# 4          in Cambridge, England, The United Kingdom
#
#                                           image_urls  \
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4  https://upload.wikimedia.org/wikipedia/commons...
#
#                                               images  nb_words  \
# 0  {'url': 'https://upload.wikimedia.org/wikipedi...        19
# 1  {'url': 'https://upload.wikimedia.org/wikipedi...         9
# 2  {'url': 'https://upload.wikimedia.org/wikipedi...        19
# 3  {'url': 'https://upload.wikimedia.org/wikipedi...        12
# 4  {'url': 'https://upload.wikimedia.org/wikipedi...        22
#
#                                                  url  \
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4  https://upload.wikimedia.org/wikipedia/commons...
#
#                                                 path  \
# 0  full/202f06476c6ec2028a863a18c060034b47f77caa.jpg
# 1  full/c0bc279b04d6c05b50a24cbb9bb309a12f2dbb4d.jpg
# 2  full/24594026b2fd1f9f66411dfa09e9ea1dd5ebc57e.jpg
# 3  full/66870fc7a3768d97a31863bee79977b03bca1f5e.jpg
# 4  full/3d8cb6d3ca14d6115009b8f81451a7e8c959ab1c.jpg
#
#                            checksum      status
# 0  32e019a45a472738ef82f8f1c5aeac41  downloaded
# 1  cedadbae2c90a8845a52746009097e41  downloaded
# 2  7a9a703615eef9afddd8b6adb6e84031  downloaded
# 3  daffb2c3a8a39269d10634ea8f6e6d70  downloaded
# 4  c7d0eb25865df2a395b9606950bff261  downloaded

# %% [markdown]
# ## 3. Transformer date en datetime

# %%
df['born_date'] = pd.to_datetime(df['born_date'])
df['born_date']
# Out:
# 0    1775-12-16
# 1    1945-08-14
# 2    1884-10-11
# 3    1899-04-24
# 4    1952-03-11
#         ...
# 95   1965-07-31
# 96   1926-04-28
# 97   1860-05-09
# 98   1894-10-14
# 99   1942-11-27
# Name: born_date, Length: 100, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   text           100 non-null    object
#  1   author         100 non-null    object
#  2   tags           97 non-null     object
#  3   born_date      100 non-null    datetime64[ns]
#  4   born_location  100 non-null    object
#  5   image_urls     100 non-null    object
#  6   images         100 non-null    object
#  7   nb_words       100 non-null    int64
#  8   url            100 non-null    object
#  9   path           100 non-null    object
#  10  checksum       100 non-null    object
#  11  status         100 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 9.5+ KB

# %%
df.sort_values('born_date')
# Out:
#                                                  text           author  \
# 0   “The person, be it gentleman or lady, who has ...      Jane Austen
# 89  “A lady's imagination is very rapid; it jumps ...      Jane Austen
# 72  “I declare after all there is no enjoyment lik...      Jane Austen
# 73  “There are few people whom I really love, and ...      Jane Austen
# 51  “There is nothing I would not do for those who...      Jane Austen
# ..                                                ...              ...
# 95  “The truth." Dumbledore sighed. "It is a beaut...     J.K. Rowling
# 30  “It is impossible to live without failing at s...     J.K. Rowling
# 46  “It matters not what someone is born, but what...     J.K. Rowling
# 19  “It takes a great deal of bravery to stand up ...     J.K. Rowling
# 57                 “He's like a drug for you, Bella.”  Stephenie Meyer
#
#                              tags  born_date  \
# 0   aliteracy,books,classic,humor 1775-12-16
# 89      humor,love,romantic,women 1775-12-16
# 72          books,library,reading 1775-12-16
# 73   elizabeth-bennet,jane-austen 1775-12-16
# 51                friendship,love 1775-12-16
# ..                            ...        ...
# 95                          truth 1965-07-31
# 30                            NaN 1965-07-31
# 46                     dumbledore 1965-07-31
# 19                courage,friends 1965-07-31
# 57            drug,romance,simile 1973-12-24
#
#                                         born_location  \
# 0   in Steventon Rectory, Hampshire, The United Ki...
# 89  in Steventon Rectory, Hampshire, The United Ki...
# 72  in Steventon Rectory, Hampshire, The United Ki...
# 73  in Steventon Rectory, Hampshire, The United Ki...
# 51  in Steventon Rectory, Hampshire, The United Ki...
# ..                                                ...
# 95  in Yate, South Gloucestershire, England, The U...
# 30  in Yate, South Gloucestershire, England, The U...
# 46  in Yate, South Gloucestershire, England, The U...
# 19  in Yate, South Gloucestershire, England, The U...
# 57                  in Connecticut, The United States
#
#                                            image_urls  \
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 89  https://upload.wikimedia.org/wikipedia/commons...
# 72  https://upload.wikimedia.org/wikipedia/commons...
# 73  https://upload.wikimedia.org/wikipedia/commons...
# 51  https://upload.wikimedia.org/wikipedia/commons...
# ..                                                ...
# 95  https://upload.wikimedia.org/wikipedia/commons...
# 30  https://upload.wikimedia.org/wikipedia/commons...
# 46  https://upload.wikimedia.org/wikipedia/commons...
# 19  https://upload.wikimedia.org/wikipedia/commons...
# 57  https://upload.wikimedia.org/wikipedia/commons...
#
#                                                images  nb_words  \
# 0   {'url': 'https://upload.wikimedia.org/wikipedi...        19
# 89  {'url': 'https://upload.wikimedia.org/wikipedi...        19
# 72  {'url': 'https://upload.wikimedia.org/wikipedi...        42
# 73  {'url': 'https://upload.wikimedia.org/wikipedi...        59
# 51  {'url': 'https://upload.wikimedia.org/wikipedi...        28
# ..                                                ...       ...
# 95  {'url': 'https://upload.wikimedia.org/wikipedi...        19
# 30  {'url': 'https://upload.wikimedia.org/wikipedi...        32
# 46  {'url': 'https://upload.wikimedia.org/wikipedi...        13
# 19  {'url': 'https://upload.wikimedia.org/wikipedi...        23
# 57  {'url': 'https://upload.wikimedia.org/wikipedi...         7
#
#                                                   url  \
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 89  https://upload.wikimedia.org/wikipedia/commons...
# 72  https://upload.wikimedia.org/wikipedia/commons...
# 73  https://upload.wikimedia.org/wikipedia/commons...
# 51  https://upload.wikimedia.org/wikipedia/commons...
# ..                                                ...
# 95  https://upload.wikimedia.org/wikipedia/commons...
# 30  https://upload.wikimedia.org/wikipedia/commons...
# 46  https://upload.wikimedia.org/wikipedia/commons...
# 19  https://upload.wikimedia.org/wikipedia/commons...
# 57  https://upload.wikimedia.org/wikipedia/commons...
#
#                                                  path  \
# 0   full/202f06476c6ec2028a863a18c060034b47f77caa.jpg
# 89  full/202f06476c6ec2028a863a18c060034b47f77caa.jpg
# 72  full/202f06476c6ec2028a863a18c060034b47f77caa.jpg
# 73  full/202f06476c6ec2028a863a18c060034b47f77caa.jpg
# 51  full/202f06476c6ec2028a863a18c060034b47f77caa.jpg
# ..                                                ...
# 95  full/67931e69367794fed5aba6adfce69cc8c6a2792b.jpg
# 30  full/67931e69367794fed5aba6adfce69cc8c6a2792b.jpg
# 46  full/67931e69367794fed5aba6adfce69cc8c6a2792b.jpg
# 19  full/67931e69367794fed5aba6adfce69cc8c6a2792b.jpg
# 57  full/4c34b18d81aa4362260a5bcb1c1d946666abd863.jpg
#
#                             checksum      status
# 0   32e019a45a472738ef82f8f1c5aeac41  downloaded
# 89  32e019a45a472738ef82f8f1c5aeac41  downloaded
# 72  32e019a45a472738ef82f8f1c5aeac41  downloaded
# 73  32e019a45a472738ef82f8f1c5aeac41  downloaded
# 51  32e019a45a472738ef82f8f1c5aeac41  downloaded
# ..                               ...         ...
# 95  ed591c7b7e9bf1d935519a56a252a23c  downloaded
# 30  ed591c7b7e9bf1d935519a56a252a23c  downloaded
# 46  ed591c7b7e9bf1d935519a56a252a23c  downloaded
# 19  ed591c7b7e9bf1d935519a56a252a23c  downloaded
# 57  011fad72f841b3667ef4d5125e25987e  downloaded
#
# [100 rows x 12 columns]

# %%
df.set_index('born_date')
# Out:
#                                                          text  \
# born_date
# 1775-12-16  “The person, be it gentleman or lady, who has ...
# 1945-08-14  “A day without sunshine is like, you know, nig...
# 1884-10-11  “A woman is like a tea bag; you never know how...
# 1899-04-24  “Life is what happens to us while we are makin...
# 1952-03-11  “I may not have gone where I intended to go, b...
# ...                                                       ...
# 1965-07-31  “The truth." Dumbledore sighed. "It is a beaut...
# 1926-04-28  “You never really understand a person until yo...
# 1860-05-09         “To die will be an awfully big adventure.”
# 1894-10-14  “It takes courage to grow up and become who yo...
# 1942-11-27  “I'm the one that's got to die when it's time ...
#
#                        author  \
# born_date
# 1775-12-16        Jane Austen
# 1945-08-14       Steve Martin
# 1884-10-11  Eleanor Roosevelt
# 1899-04-24     Allen Saunders
# 1952-03-11      Douglas Adams
# ...                       ...
# 1965-07-31       J.K. Rowling
# 1926-04-28         Harper Lee
# 1860-05-09        J.M. Barrie
# 1894-10-14      E.E. Cummings
# 1942-11-27       Jimi Hendrix
#
#                                                          tags  \
# born_date
# 1775-12-16                      aliteracy,books,classic,humor
# 1945-08-14                               humor,obvious,simile
# 1884-10-11                    misattributed-eleanor-roosevelt
# 1899-04-24  fate,life,misattributed-john-lennon,planning,p...
# 1952-03-11                                    life,navigation
# ...                                                       ...
# 1965-07-31                                              truth
# 1926-04-28                                better-life-empathy
# 1860-05-09                                     adventure,love
# 1894-10-14                                            courage
# 1942-11-27                                         death,life
#
#                                                 born_location  \
# born_date
# 1775-12-16  in Steventon Rectory, Hampshire, The United Ki...
# 1945-08-14                  in Waco, Texas, The United States
# 1884-10-11                               in The United States
# 1899-04-24                               in The United States
# 1952-03-11          in Cambridge, England, The United Kingdom
# ...                                                       ...
# 1965-07-31  in Yate, South Gloucestershire, England, The U...
# 1926-04-28         in Monroeville, Alabama, The United States
# 1860-05-09  in Kirriemuir, Angus, Scotland, The United Kin...
# 1894-10-14     in Cambridge, Massachusetts, The United States
# 1942-11-27          in Seattle, Washington, The United States
#
#                                                    image_urls  \
# born_date
# 1775-12-16  https://upload.wikimedia.org/wikipedia/commons...
# 1945-08-14  https://upload.wikimedia.org/wikipedia/commons...
# 1884-10-11  https://upload.wikimedia.org/wikipedia/commons...
# 1899-04-24  https://upload.wikimedia.org/wikipedia/en/thum...
# 1952-03-11  https://upload.wikimedia.org/wikipedia/commons...
# ...                                                       ...
# 1965-07-31  https://upload.wikimedia.org/wikipedia/commons...
# 1926-04-28  https://upload.wikimedia.org/wikipedia/commons...
# 1860-05-09  https://upload.wikimedia.org/wikipedia/commons...
# 1894-10-14  https://upload.wikimedia.org/wikipedia/commons...
# 1942-11-27  https://upload.wikimedia.org/wikipedia/commons...
#
#                                                        images  nb_words  \
# born_date
# 1775-12-16  {'url': 'https://upload.wikimedia.org/wikipedi...        19
# 1945-08-14  {'url': 'https://upload.wikimedia.org/wikipedi...         9
# 1884-10-11  {'url': 'https://upload.wikimedia.org/wikipedi...        19
# 1899-04-24  {'url': 'https://upload.wikimedia.org/wikipedi...        12
# 1952-03-11  {'url': 'https://upload.wikimedia.org/wikipedi...        22
# ...                                                       ...       ...
# 1965-07-31  {'url': 'https://upload.wikimedia.org/wikipedi...        19
# 1926-04-28  {'url': 'https://upload.wikimedia.org/wikipedi...        27
# 1860-05-09  {'url': 'https://upload.wikimedia.org/wikipedi...         8
# 1894-10-14  {'url': 'https://upload.wikimedia.org/wikipedi...        12
# 1942-11-27  {'url': 'https://upload.wikimedia.org/wikipedi...        25
#
#                                                           url  \
# born_date
# 1775-12-16  https://upload.wikimedia.org/wikipedia/commons...
# 1945-08-14  https://upload.wikimedia.org/wikipedia/commons...
# 1884-10-11  https://upload.wikimedia.org/wikipedia/commons...
# 1899-04-24  https://upload.wikimedia.org/wikipedia/en/thum...
# 1952-03-11  https://upload.wikimedia.org/wikipedia/commons...
# ...                                                       ...
# 1965-07-31  https://upload.wikimedia.org/wikipedia/commons...
# 1926-04-28  https://upload.wikimedia.org/wikipedia/commons...
# 1860-05-09  https://upload.wikimedia.org/wikipedia/commons...
# 1894-10-14  https://upload.wikimedia.org/wikipedia/commons...
# 1942-11-27  https://upload.wikimedia.org/wikipedia/commons...
#
#                                                          path  \
# born_date
# 1775-12-16  full/202f06476c6ec2028a863a18c060034b47f77caa.jpg
# 1945-08-14  full/c0bc279b04d6c05b50a24cbb9bb309a12f2dbb4d.jpg
# 1884-10-11  full/24594026b2fd1f9f66411dfa09e9ea1dd5ebc57e.jpg
# 1899-04-24  full/66870fc7a3768d97a31863bee79977b03bca1f5e.jpg
# 1952-03-11  full/3d8cb6d3ca14d6115009b8f81451a7e8c959ab1c.jpg
# ...                                                       ...
# 1965-07-31  full/67931e69367794fed5aba6adfce69cc8c6a2792b.jpg
# 1926-04-28  full/96607c152fbe0f7b087071cbacc0fcc4564e689e.jpg
# 1860-05-09  full/593de0e753650ca7db0f4ba06c3a817eda9a6097.jpg
# 1894-10-14  full/6525c1237b89c4e61b59135af3e113c4d7886cf6.jpg
# 1942-11-27  full/2c05e574ed6e581ea3bebf8bf3d34152e2d1badc.jpg
#
#                                     checksum      status
# born_date
# 1775-12-16  32e019a45a472738ef82f8f1c5aeac41  downloaded
# 1945-08-14  cedadbae2c90a8845a52746009097e41  downloaded
# 1884-10-11  7a9a703615eef9afddd8b6adb6e84031  downloaded
# 1899-04-24  daffb2c3a8a39269d10634ea8f6e6d70  downloaded
# 1952-03-11  c7d0eb25865df2a395b9606950bff261  downloaded
# ...                                      ...         ...
# 1965-07-31  ed591c7b7e9bf1d935519a56a252a23c  downloaded
# 1926-04-28  6b444543b30ba48245250129104e308a  downloaded
# 1860-05-09  c9d66519811f5a5c7c7c969a7d23aec5  downloaded
# 1894-10-14  2fd132722c4e5344d6326da8abf05484  downloaded
# 1942-11-27  c3bcf135727dac6e22fd88a7405cb4b0  downloaded
#
# [100 rows x 11 columns]
