# %% [markdown]
# # GLOBAL SHARK ATTACK

# %% [markdown]
# ## Importation des données des requins

# %%
import pandas as pd

# %%
df = pd.read_csv('global-shark-attack.csv', sep=';')
df
# Out:
#        Case Number        Date    Year        Type              Country  \
# 0       2018.05.21  2018-05-21  2018.0  Unprovoked                  USA
# 1       2018.03.31  2018-03-31  2018.0  Unprovoked                  USA
# 2       2017.12.31  2017-12-31  2017.0  Unprovoked                  USA
# 3     2017.11.30.b  2017-11-30  2017.0  Unprovoked           COSTA RICA
# 4     2017.09.24.b  2017-09-24  2017.0     Invalid                  USA
# ...            ...         ...     ...         ...                  ...
# 6296       ND.0081         NaN     NaN     Invalid                  USA
# 6297       ND.0047         NaN     NaN  Unprovoked  NORTH PACIFIC OCEAN
# 6298       ND.0022         NaN     NaN  Unprovoked            AUSTRALIA
# 6299       ND.0018         NaN     NaN  Unprovoked              VIETNAM
# 6300           NaN         NaN     NaN         NaN                  NaN
#
#                            Area                           Location  \
# ...

# %% [markdown]
# ## Découverte des données

# %%
df.shape
# Out:
# (6301, 22)

# %% [markdown]
# * 6301 lignes
# * 22 colonnes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6301 entries, 0 to 6300
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6294 non-null   object
#  1   Date                    6000 non-null   object
#  2   Year                    6166 non-null   float64
#  3   Type                    6289 non-null   object
#  4   Country                 6243 non-null   object
#  5   Area                    5838 non-null   object
#  6   Location                5752 non-null   object
#  7   Activity                5747 non-null   object
#  8   Name                    6083 non-null   object
#  9   Sex                     5735 non-null   object
#  10  Age                     3462 non-null   object
#  11  Injury                  6265 non-null   object
#  12  Fatal (Y/N)             6301 non-null   object
#  13  Time                    2938 non-null   object
# ...

# %%
df.describe()
# Out:
#               Year  original order
# count  6166.000000     6299.000000
# mean   1966.518164     3150.999682
# std      57.683303     1818.509455
# min       1.000000        2.000000
# 25%    1944.000000     1576.500000
# 50%    1979.000000     3151.000000
# 75%    2005.000000     4725.500000
# max    2018.000000     6300.000000

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum()
# Out:
# Case Number                  7
# Date                       301
# Year                       135
# Type                        12
# Country                     58
# Area                       463
# Location                   549
# Activity                   554
# Name                       218
# Sex                        566
# Age                       2839
# Injury                      36
# Fatal (Y/N)                  0
# Time                      3363
# Species                   2850
# Investigator or Source      25
# pdf                          8
# href formula                 9
# href                         8
# Case Number.1                7
# Case Number.2                7
# original order               2
# dtype: int64

# %% [markdown]
# * 'Case Number' semble être dupliqué en 3 ??? ('Case Number', 'Case Number.1', 'Case Number.2')
# * 'Date' et 'Year' ??? La date devrait contenir l'année. Ajouté l'année à 'Date'?
# *

# %% [markdown]
# ### 'Case Number'

# %% [markdown]
# Il se peut que 'Case Number' soit duppliquer 3 fois. ('Case Number', 'Case Number.1', 'Case Number.2')
# Vérifion cela en comparant les colonnes.
# Si elles sont totalement identique, nous pouvons en supprimer.

# %%
df_cn = df[['Case Number', 'Case Number.1', 'Case Number.2']]
df_cn
# Out:
#        Case Number Case Number.1 Case Number.2
# 0       2018.05.21    2018.05.21    2018.05.21
# 1       2018.03.31    2018.03.31    2018.03.31
# 2       2017.12.31    2017.12.31    2017.12.31
# 3     2017.11.30.b  2017.11.30.b  2017.11.30.b
# 4     2017.09.24.b  2017.09.24.b  2017.09.24.b
# ...            ...           ...           ...
# 6296       ND.0081       ND.0081       ND.0081
# 6297       ND.0047       ND.0047       ND.0047
# 6298       ND.0022       ND.0022       ND.0022
# 6299       ND.0018       ND.0018       ND.0018
# 6300           NaN           NaN           NaN
#
# [6301 rows x 3 columns]

# %%
(df_cn['Case Number'] != df_cn['Case Number.1']).sum()
# Out:
# 7

# %%
(df_cn['Case Number'] != df_cn['Case Number.2']).sum()
# Out:
# 7

# %% [markdown]
# ('Case Number' == 'Case Number.1' == 'Case Number.2')
#
# On peut donc supprimer 2 'Case Number'

# %%
df.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# dtype: object
